# %%
#task 1
def welcome_message():
    print("Welcome to Python ")

welcome_message()
# Out:
# Welcome to Python

# %%
#task 2
def add_numbers(a, b):

    return a + b

result = add_numbers(99, 77)

print("The sum is:", result)
# Out:
# The sum is: 176

# %%
# task 3
def functionA():
    print("Inside Function A")
    functionB()

def functionB():
    print("Inside Function B")

functionA()
# Out:
# Inside Function A
# Inside Function B

# %%
# task 4
def greet(name="student"):
    print("hello", name)

greet()
greet("Aizaz")
# Out:
#   File "/tmp/ipykernel_311/402407962.py", line 2
#     def greet(name="student");
#                              ^
# SyntaxError: expected ':'

# %%
# task 4
def greet(name="student"):
    print("hello", name)

greet()
greet("Aizaz")
# Out:
# hello student
# hello Aizaz

# %%
# task 5
x = 20
def show_function():
  print("Global x =" ,x)

  y = 40
  print("local y =" , x)

  show_function()
  print("outside function , x =" , x)
    print("outside function , y =" , y)
# Out:
#   File "/tmp/ipykernel_311/3589518704.py", line 11
#     print("outside function , y =" , y)
#     ^
# IndentationError: unexpected indent

# %%
# task 5
def total_numbers(*numbers):
  total = sum(numbers)
  return total

# The print statement was unreachable and had an extra parenthesis. It should be outside the function to print its result.
print("total number is : ", total_numbers(20,20,40,60,90,22,77,99,77,22))
# Out:
#   File "/tmp/ipykernel_311/2020602731.py", line 5
#     print("total number is : "),total_numbers(20,20,40,60,90,22,77,99,77,22,))
#                                                                              ^
# SyntaxError: unmatched ')'

# %%
def total_numbers(*numbers):
    total = sum(numbers)
    print("Total numbers is:", total)
    return total

total_numbers(22, 44, 55, 88, 99, 44, 12, 78, 43)
# Out:
# Total numbers is: 485
# 485

# %%
# task 6
def total_numbers(*numbers):
    total = 0
    for num in numbers:
        total += num
    return total

result = total_numbers(99, 88, 44, 55)
print(result)
# Out:
# 286

# %%
# task 7
def student_info(**data):
    for key, value in data.items():
        print(key, ":", value)

student_info(name="Aizaz", age=20, course="AI")
# Out:
# name : Aizaz
# age : 20
# course : AI

# %%
#task 8
square = lambda x: x * x

print(square(5))
# Out:
# 25

# %%
# task 9
numbers = [1, 2, 3, 4, 5]

squares = list(map(lambda x: x * x, numbers))

print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
# task 10
marks = [45, 67, 82, 30, 90, 55]

result = list(filter(lambda x: x > 50, marks))

print(result)
# Out:
# [67, 82, 90, 55]
